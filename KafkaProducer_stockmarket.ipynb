# %%
pip install kafka-python
# Out:
# Requirement already satisfied: kafka-python in /usr/local/lib/python3.10/dist-packages (2.0.2)

# %%
import pandas as pd
from kafka import KafkaProducer
from time import sleep
from json import dumps
import json

# %%
producer = KafkaProducer(bootstrap_servers=['3.82.222.172:9092'], #change ip here
                         value_serializer=lambda x:
                         dumps(x).encode('utf-8'))

# %%
producer.send('jayanth1', value={'name':'balhna'})

# %%
df = pd.read_csv("sample_data/indexProcessed.csv")

# %%
df.head()
# Out:
#   Index        Date         Open         High          Low        Close  \
# 0   HSI  1986-12-31  2568.300049  2568.300049  2568.300049  2568.300049
# 1   HSI  1987-01-02  2540.100098  2540.100098  2540.100098  2540.100098
# 2   HSI  1987-01-05  2552.399902  2552.399902  2552.399902  2552.399902
# 3   HSI  1987-01-06  2583.899902  2583.899902  2583.899902  2583.899902
# 4   HSI  1987-01-07  2607.100098  2607.100098  2607.100098  2607.100098
#
#      Adj Close  Volume    CloseUSD
# 0  2568.300049     0.0  333.879006
# 1  2540.100098     0.0  330.213013
# 2  2552.399902     0.0  331.811987
# 3  2583.899902     0.0  335.906987
# 4  2607.100098     0.0  338.923013

# %%
while True:
    dict_stock = df.sample(1).to_dict(orient="records")[0]
    producer.send('jayanth1', value=dict_stock)
# Out:
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.client:<BrokerConnection node_id=0 host=3.82.222.172:9092 <connected> [IPv4 ('3.82.222.172', 9092)]> timed out after 30000 ms. Closing connection.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.client:<BrokerConnection node_id=0 host=3.82.222.172:9092 <connected> [IPv4 ('3.82.222.172', 9092)]> timed out after 30000 ms. Closing connection.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# ...
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# WARNING:kafka.producer.record_accumulator:Produced messages to topic-partition TopicPartition(topic='jayanth1', partition=0) with base offset -1 log start offset None and error None.
# WARNING:kafka.producer.record_accumulator:Expired 1 batches in accumulator
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-9f3db8d83ced> in <cell line: 1>()
#       1 while True:
# ----> 2     dict_stock = df.sample(1).to_dict(orient="records")[0]
#       3     producer.send('jayanth1', value=dict_stock)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    6027             weights = sample.preprocess_weights(self, weights, axis)
#    6028
# -> 6029         sampled_indices = sample.sample(obj_len, size, replace, weights, rs)
#    6030         result = self.take(sampled_indices, axis=axis)
#    6031
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/sample.py in sample(obj_len, size, replace, weights, random_state)
#     150             raise ValueError("Invalid weights: weights sum to zero")
#     151
# --> 152     return random_state.choice(obj_len, size=size, replace=replace, p=weights).astype(
#     153         np.intp, copy=False
#     154     )
#
# KeyboardInterrupt:

# %%
producer.flush() #clear data from kafka server
